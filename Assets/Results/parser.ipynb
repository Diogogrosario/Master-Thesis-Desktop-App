# %%
import pandas as pd

df1 = pd.read_csv("user16_task1_data_False.csv",index_col=False)
matched_rows = df1[df1["Action"] == "Hit"]
average1 = matched_rows["TimeToHit"].mean()

df2 = pd.read_csv("user16_task2_data_False.csv",index_col=False)
matched_rows = df2[df2["Action"] == "Hit"]
average2 = matched_rows["TimeToHit"].mean()

df3 = pd.read_csv("user16_task3_data_False.csv",index_col=False)
matched_rows = df3[df3["Action"] == "Hit"]
average3 = matched_rows["TimeToHit"].mean()

df4 = pd.read_csv("user16_task4_data_False.csv",index_col=False)
matched_rows = df4[df4["Action"] == "Hit"]
average4 = matched_rows["TimeToHit"].mean()

df5 = pd.read_csv("user16_task5_data_False.csv",index_col=False)
matched_rows = df5[df5["Action"] == "Hit"]
average5 = matched_rows["TimeToHit"].mean()

df6 = pd.read_csv("user16_task6_data_False.csv",index_col=False)
matched_rows = df6[df6["Action"] == "Hit"]
average6 = matched_rows["TimeToHit"].mean()

df7 = pd.read_csv("user16_task1_data_True.csv",index_col=False)
matched_rows = df7[df7["Action"] == "Hit"]
average7 = matched_rows["TimeToHit"].mean()

df8 = pd.read_csv("user16_task2_data_True.csv",index_col=False)
matched_rows = df8[df8["Action"] == "Hit"]
average8 = matched_rows["TimeToHit"].mean()

df9 = pd.read_csv("user16_task3_data_True.csv",index_col=False)
matched_rows = df9[df9["Action"] == "Hit"]
average9 = matched_rows["TimeToHit"].mean()

df10 = pd.read_csv("user16_task4_data_True.csv",index_col=False)
matched_rows = df10[df10["Action"] == "Hit"]
average10 = matched_rows["TimeToHit"].mean()

df11 = pd.read_csv("user16_task5_data_True.csv",index_col=False)
matched_rows = df11[df11["Action"] == "Hit"]
average11 = matched_rows["TimeToHit"].mean()

df12 = pd.read_csv("user16_task6_data_True.csv",index_col=False)
matched_rows = df12[df12["Action"] == "Hit"]
average12 = matched_rows["TimeToHit"].mean()

print(average1)
print(average2)
print(average3)
print(average4)
print(average5)
print(average6)
print(average7)
print(average8)
print(average9)
print(average10)
print(average11)
print(average12)

custom_row = {
    "Participant": 16,
    "T1Projeçao": average7,
    "T2Projeçao": average8,
    "T3Projeçao": average9,
    "T4Projeçao": average10,
    "T5Projeçao": average11,
    "T6Projeçao": average12,
    "T1Baseline": average1,
    "T2Baseline": average2,
    "T3Baseline": average3,
    "T4Baseline": average4,
    "T5Baseline": average5,
    "T6Baseline": average6
}

# Create a DataFrame with the custom row
df = pd.DataFrame([custom_row])

# Specify the filename of the existing CSV file
filename = "averageTimes.csv"

# Append the DataFrame to the existing CSV file
df.to_csv(filename, mode='a', index=False, header=False)
# Out:
# 1.353917525
# 4.72973874
# nan
# 1.1110188702702701
# 2.1096529739130436
# 4.077742166666666
# 1.4523654243902437
# 3.0942861111111113
# 2.42143015
# 2.3093682083333333
# 2.0617777703703704
# 3.1865745333333333

# %%
import pandas as pd

# Loop over the user IDs
for user_id in range(0, 24):
    # Create a DataFrame to store the time_to_hit_values
    df_time = pd.DataFrame(columns=["Participant"])
    df_time["Participant"] = [f"user{user_id}"]

    # Loop over the task IDs
    for task_id in range(1, 7):
        # Generate the file name based on the user and task IDs
        filename = f"user{user_id}_task{task_id}_data_False.csv"
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(filename, index_col=False)
        
        # Filter rows where the column value matches "Hit"
        hit_rows = df[df["Action"] == "Hit"]
        
        # Get the values of the "TimeToHit" column from the filtered rows
        time_to_hit_values = hit_rows["TimeToHit"].tolist()
        
        task_df = pd.DataFrame({f"T{task_id}": time_to_hit_values})
        
        # Concatenate the task DataFrame with the df_time DataFrame
        df_time = pd.concat([df_time, task_df], axis=1)
    
        df_time.to_csv(f"user{user_id}_Baseline.csv", index=False)

        # Loop over the task IDs

    df_time = pd.DataFrame(columns=["Participant"])
    df_time["Participant"] = [f"user{user_id}"]
    
    for task_id in range(1, 7):
        # Generate the file name based on the user and task IDs
        filename = f"user{user_id}_task{task_id}_data_True.csv"
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(filename, index_col=False)
        
        # Filter rows where the column value matches "Hit"
        hit_rows = df[df["Action"] == "Hit"]
        
        # Get the values of the "TimeToHit" column from the filtered rows
        time_to_hit_values = hit_rows["TimeToHit"].tolist()
        
        task_df = pd.DataFrame({f"T{task_id}": time_to_hit_values})
        
        # Concatenate the task DataFrame with the df_time DataFrame
        df_time = pd.concat([df_time, task_df], axis=1)
    
        df_time.to_csv(f"user{user_id}_Projection.csv", index=False)
